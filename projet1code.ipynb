# %% [markdown]
# # FE652 Group Work Project 1
#
#
# 1. **Tchawou Francky Kevin**

# %% [markdown]
# #Step 1: Definition of Fama/French 5 Factors
# a. Collectively, define each of the 5 factors, one per page.
#
# b. Write a non-technical paragraph (NO MORE!) as to why this factor helps to
# explain returns. Be sure to use professional references (NOT Wikipedia)
# for these sections.

# %% [markdown]
# ## Market Risk Premium (Rm-Rf)
# **Technical :**
#
# Rm-Rf is a critical component of the Capital Asset Pricing Model (CAPM) and represents Market Risk Premium.
# CAPM is a way to predict expected return on a certain stock based on Beta i.e. systematic risk(how does your stock correlate with the Market). Beta is the standardized measure of the covariance of the assets return with the market return.
# β represents the asset's sensitivity to market movements.
#
# In the CAPM, the expected return of an asset is calculated using the formula:
# $$
# Expected Return =𝑅𝑓 + 𝛽 ×(𝑅𝑚−𝑅𝑓)
# $$
#
# 𝑅𝑚−𝑅𝑓 is Market Risk Premium (MRP), instead from risk free assets the return that investors expects to earn from holding a risky market portfolio.It is the difference between the return on the market portfolio (Rm) and the risk-free rate(Rf).
# MRP (𝑅𝑚−𝑅𝑓) is a crucial input that affects the expected return based on the asset's risk relative to the market. The magnitude of this MRP is influenced by different factors (economic conditions, sentiment of investors, risk environment overall).
#
# Rm typically represented by a borad market index (such as S&P 500 ) and reflects overall performance of the equity market.
# Rf is the return on an investment with 0 risk, often represented by stable securities vritually free of default risk such as US Treasury bills.
#
#
# **Non-Technical:**
#
# Investors can make more informed decisions about where to allocate their capital by comparing the expected return of an asset to the Market Risk premium (𝑅𝑚−𝑅𝑓).
#
# We all understand concept of risk vs reward.
# For bearing systematic risk which cannot be diversifed, for taking on the risk of investing in the market as a whole, investors expect to be rewarded.
# Reflecting the overall market sentiment and economic conditions
# MRP provides a benchmark for assessing the risk and return of individual assets or portfolios.

# %% [markdown]
# ## Small Minus Big (SMB)
#
# **Technical :**
#
# Small Cap Outperform large Cap (Size Effect)
#
# Fema and French expands CAPM and added size effect (Small minus Big) to the formula and Value of stock (High minus Low).
#
# In CAPM, we are using one factor model to calculate expected return.
# Expected Return =𝑅𝑓 + 𝛽 ×(𝑅𝑚−𝑅𝑓)
# Frema-French  Model expands CAPM and adds SMB (size of the stock) and HML(value of the stock).
# Expected Return =𝑅𝑓 + 𝛽 ×(𝑅𝑚−𝑅𝑓) + SMB	+ HML
#
# Small Minus Big(SMB) is a factor that captures size effect, measures the additional return investors have historically received by investing in small-cap stocks compared to large-cap stocks. Smaller firms tend to outperform larger firms over the long term as analysts pay close attention to large firms and information is efficient compared to small firms.  SMB is calculated by taking the difference in returns between a portfolio of small-cap stocks and a portfolio of large-cap stocks.
#
# **Non-Technical :**
#
# Small minus big (SMB), it is small capitalization. Looking at small cap stocks vs large cap stocks, for example Apple computer has large capitalization 1 Trillion(# of shares * stock market price)and Papa Jones (1.42 Billion). Analysts follow large cap stocks closely like Apple more than Papa JOnes, better informed investors with media coverage, the prices of large cap stocks reflects true value and they are less susceptable, less systematic risk, systematic markets, everything is known becuase they are followed as everyone is evaluating them and we have more information about large caps, more info , less risk.
#
# Shares of large firms may be less risky than those of small firms, other things being equal, as they are covered by more analysts, and there is more accurate information about them.
# With better-informed investors, prices will more accurately reflect true value and be less susceptible to systematic as well as firm-specific flutuations.
# Shares of large firms with deeper pockets and greater debt capacity, large firms also can better witstand economic downturns.
# Because of both above reasons, small firms will command higher risk premiums than indicated by beta alone.
#
#
# By including SMB in a model, enhancing the explanatory power of the model in predicting asset returns, investors can account for the additional return that small-cap stocks provide.

# %% [markdown]
# ## High Minus Low (HML)
#
# HML is one of the supplemental and irregular factors added to CAPM with SML (explained in previous section), established under Fama-French 3 Factor model. HML, or known as High-minus-Low is used to measure the return difference between the portfolio with high Book-to-Market (BM) value and portfolio with small BM (Fama & French, 1995). In FF3 model equation, the factor return of HML is expected premium, accompanied with factor loading known as hi. Researchers believe that the inclusive of SML and HML can provide more comprehensive prediction on expected return (Fama & French, 1996)
#
# $$
#  h_i HML
# $$
#
# where $$h_i$$ is factor loading.
#
# For HML factor return, it can be calculated as per the equation below (Tarek & Suret, 2004),
#
#
# $$
# HML = \frac{((S/H)-(S/L))+((B/H)-(B/L))}{2}
# $$
#
#
# The symbol representation are shown as follow:
# B and S (Big and Small Sizes in relative to Market Equity)
# H and L (High and Low Book-to-Market (BM)); where H corresponds to 70% or higher of BM breakpoints, and L corresponds to 30% or lower of BM breakpoints.
#
# The equation above also represents as equally weight average of the return on the value portfolio minus on the growth portfolio. S/H, S/L, B/H and B/L are also known as intersection of size and Book-to-Market groups. Other researchers also define HML as the return differential between the average value and the average growth portfolios.
#
# **Non-Technical**
#
# Fama and French discovered that firms with high BM and positive slopes on HML is generally low performed companies (or known as glamou stocks),; and good performed companies generally has low BM and negative slopes on HML (Fama & French, 1995). Therefore, the future expected return of low performed companies is higher than good performed companies, that leads to compensation of owning a high risk asset. (Fama & French, 1996)
#
# Some researchers also suggested that several characteristic suc has book to market value, earning ratio and post sales growth ratio are fall under HML (Kumar & Sehgal, 20004)
#
# However, solely relying on SMB and HML might not be comprehensive enough to predict a robust expected return, as it may miss out those low expected return of small companies that they could not be ignored due to continuous large investment amount from public, even the profitability is low (Fama & French, 2014). Additional factor will be explained in the following section.

# %% [markdown]
# ## Conservative Minus Aggressive (CMA)
# 1-a) CMA (Conservative Minus Aggressive) is one of the two factors added by farma-french to the three-factor FF3 model to form the five-factor FF5 model. It is about investment. It represents the average return of two conservative investment portfolios minus the average return of two aggressive investment portfolios. In other words, it reflects the difference between the returns on diversified portfolios of shares in low-investment and high-investment companies, which we call conservative and aggressive.
#
# 2-b)
# an investment with a low CMA per event means that the reinvestment ratio is low per event
# A portfolio with positive CMA exposure will therefore tend to outperform when conservative companies outperform aggressive ones, which is very often the case in periods of low economic growth or high risk.

# %% [markdown]
# ## Robust Minus Weak (RMW)
# 1-a)
# Robust Minus Weak (RMW):The gross profitability factor captures the relative performance of companies with high profitability compared to those with low profitability. This factor can be considered as a special version of the value strategy based on gross profitability, so exposure to this factor can in fact represent the deviation of the share price from value. In other words, it is the average return of the two portfolios with strong operating profitability minus the average return of the two portfolios with weak operating profitability.
#
# 1-b)
# It should be noted that portfolios with positive exposure to RMW will tend to outperform when companies with high profitability outperform those with low profitability. This very often reflects good management and financial resilience.

# %% [markdown]
# # Step 2: Study on Fama/French 5 Factor Daily Data
# a. Import, structure, and graph the daily factor returns.
# b. Collect and compute correlations of the changes in the factor returns.
# c. Collect economic data of your choice during that 2-year period (for
# example, inflation rates, 10-year Treasury rates, etc.)

# %% [markdown]
# In this section, we have downloaded Fama/French 5 Factors (2x3) [Daily] to understand the trend of daily factor return across the specified period.
#
# We have extracted the data in recent 3-year time period (1 May 2021 to 31 May 2024)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Step 2a1; Import the daily factor return
# Define url_1 as Developed FF5 Factor
# Define url_2 as Developed 6 portfolios from Kenneth French
url_1 = 'https://drive.google.com/uc?export=download&id=1ZAoliuM-l81ij3HALLCBKAzp1fEYv-aV'
url_2 = 'https://drive.google.com/uc?export=download&id=1LiZ7SyJiKWYFbaiwGbh93BdpE35LFtX-'
FF5_df = pd.read_csv(url_1)
portfolio_df = pd.read_csv(url_2)

FF5_df['Date'] = pd.to_datetime(FF5_df['Date'], format='%Y%m%d')
portfolio_df['Date'] = pd.to_datetime(portfolio_df['Date'], format='%Y%m%d')

# %%
#Step 2a2: Structure the data for 3 years period
# Filter data for the chosen period
start_date = '2021-05-01'
end_date = '2024-05-31'
mask = (FF5_df['Date'] >= start_date) & (FF5_df['Date'] <= end_date)
FF5_df1 = FF5_df.loc[mask]
portfolio_df1 = portfolio_df.loc[mask]

# %%
FF5_df1
# Out:
#            Date  Mkt-RF   SMB   HML   RMW   CMA    RF
# 8045 2021-05-03    0.42  0.25  0.89  0.35  0.79  0.00
# 8046 2021-05-04   -0.93 -0.10  1.40  0.33  0.75  0.00
# 8047 2021-05-05    0.42 -0.09  0.80  0.13  0.52  0.00
# 8048 2021-05-06    0.62 -0.47  1.24  0.27  0.78  0.00
# 8049 2021-05-07    1.03  0.42  0.00 -0.04  0.06  0.00
# ...         ...     ...   ...   ...   ...   ...   ...
# 8845 2024-05-27    0.20  0.23  0.06  0.00  0.03  0.02
# 8846 2024-05-28   -0.19  0.00 -0.09  0.21 -0.70  0.02
# 8847 2024-05-29   -1.06 -0.32 -0.27  0.19  0.16  0.02
# 8848 2024-05-30   -0.10  1.09  0.64 -0.34  0.63  0.02
# 8849 2024-05-31    0.74  0.07  0.58  0.06  0.54  0.02
#
# [805 rows x 7 columns]

# %%
portfolio_df1
# Out:
#            Date  SMALL LoBM  ME1 BM2  SMALL HiBM  BIG LoBM  ME2 BM2  BIG HiBM
# 8045 2021-05-03        0.11     0.53        1.02      0.04     0.46      0.90
# 8046 2021-05-04       -1.96    -1.10       -0.45     -1.53    -0.66     -0.25
# 8047 2021-05-05        0.10     0.31        0.58      0.05     0.44      1.17
# 8048 2021-05-06       -0.88     0.22        0.79      0.35     0.72      1.16
# 8049 2021-05-07        1.44     1.46        1.36      1.01     0.90      1.09
# ...         ...         ...      ...         ...       ...      ...       ...
# 8845 2024-05-27        0.51     0.44        0.42      0.11     0.27      0.32
# 8846 2024-05-28       -0.18    -0.29       -0.13      0.02    -0.42     -0.21
# 8847 2024-05-29       -1.51    -1.38       -1.34     -0.69    -1.30     -1.39
# 8848 2024-05-30        1.23     0.83        0.98     -0.66    -0.17      0.87
# 8849 2024-05-31        0.70     0.81        0.98      0.31     1.08      1.19
#
# [805 rows x 7 columns]

# %%
# Step 2a3: Graph the data
required_columns = ['Mkt-RF','SMB', 'HML', 'RMW', 'CMA']

# Step 3: Graph the daily factor returns
plt.figure(figsize=(14, 8))
for column in required_columns:
    plt.plot(FF5_df1['Date'],FF5_df1[column], label=column)

plt.title('Daily Factor Returns (1 May 2021 to 31 May 2024)')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Step 2b: Compute correlations of the change in daily factor returns
required_columns = ['Date','Mkt-RF','SMB', 'HML', 'RMW', 'CMA']
df_diff = FF5_df1[required_columns].set_index('Date').diff().dropna()
correlation_matrix = df_diff[required_columns[1:]].corr()

print("Changes in factor returns with dates:")
print(df_diff)

print("\nCorrelation matrix of the changes in factor returns:")
print(correlation_matrix)

# Plot the correlation matrix
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Factor Returns (2021-2024)')
plt.show()
# Out:
# Changes in factor returns with dates:
#             Mkt-RF   SMB   HML   RMW   CMA
# Date
# 2021-05-04   -1.35 -0.35  0.51 -0.02 -0.04
# 2021-05-05    1.35  0.01 -0.60 -0.20 -0.23
# 2021-05-06    0.20 -0.38  0.44  0.14  0.26
# 2021-05-07    0.41  0.89 -1.24 -0.31 -0.72
# 2021-05-10   -1.74 -0.60  1.39  0.23  0.86
# ...            ...   ...   ...   ...   ...
# 2024-05-27   -0.27  0.28 -0.30 -0.04  0.22
# 2024-05-28   -0.39 -0.23 -0.15  0.21 -0.73
# 2024-05-29   -0.87 -0.32 -0.18 -0.02  0.86
# 2024-05-30    0.96  1.41  0.91 -0.53  0.47
# 2024-05-31    0.84 -1.02 -0.06  0.40 -0.09
#
# [804 rows x 5 columns]
#
# Correlation matrix of the changes in factor returns:
#           Mkt-RF       SMB       HML       RMW       CMA
# Mkt-RF  1.000000 -0.357974 -0.336588 -0.173890 -0.534410
# SMB    -0.357974  1.000000  0.296115 -0.317154  0.190557
# HML    -0.336588  0.296115  1.000000 -0.207588  0.800022
# RMW    -0.173890 -0.317154 -0.207588  1.000000  0.100311
# ...

# %%
# Step 2c
# Import economic data
import numpy as np
import pandas_datareader.data as web
import pandas as pd
import matplotlib.pyplot as plt

start_date = '2021-05-01'
end_date = '2024-05-31'

# Download data from FRED - inflation rates (CPIAUCSL) and 10-year Treasury rates (GS10)
inflation = web.DataReader('CPIAUCSL', 'fred', start_date, end_date)
treasury_10yr = web.DataReader('GS10', 'fred', start_date, end_date)

inflation = inflation.resample('D').ffill()
treasury_10yr = treasury_10yr.resample('D').ffill()

# Calculate daily inflation rate changes
inflation['Daily Change'] = inflation['CPIAUCSL'].pct_change()

# Combine the data into a single DataFrame
economic_data = pd.DataFrame({
    'Inflation Rate Change': inflation['Daily Change'],
    '10-Year Treasury Rate': treasury_10yr['GS10']
})

# Display basic statistics
economic_stats = economic_data.describe()
print("Printing Economic Data Statistics for the date range May-2021 thru May-2024:")
print(economic_stats)

# Plot the economic data
plt.figure(figsize=(14, 8))

plt.subplot(2, 1, 1)
plt.plot(inflation.index, inflation['Daily Change'], label='Daily Inflation Rate Change')
plt.title('Economic Data - Daily Inflation Rate Changes (May-2021 thru May-2024)')
plt.ylabel('Daily Change')
plt.legend()
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(treasury_10yr.index, treasury_10yr['GS10'], label='10-Year Treasury Rate')
plt.title('Economic Data - Daily 10-Year Treasury Rates (May-2021 thru May-2024)')
plt.xlabel('Date')
plt.ylabel('10-Year Treasury Rate (%)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Printing Economic Data Statistics for the date range May-2021 thru May-2024:
#        Inflation Rate Change  10-Year Treasury Rate
# count            1096.000000            1097.000000
# mean                0.000141               3.100994
# std                 0.000947               1.106567
# min                -0.000064               1.280000
# 25%                 0.000000               1.760000
# 50%                 0.000000               3.530000
# 75%                 0.000000               4.020000
# max                 0.012483               4.800000

# %%
print("Step 2 completed")
# Out:
# Step 2 completed

# %% [markdown]
# # Step 3: Study on FF3 Beta Coefficient

# %%
# Import the FF3 Daily Factor Return
# Define url_3 as FF3 Daily Factor
url_3 = 'https://drive.google.com/uc?export=download&id=1uIs4iARRDtxyBAcaPHwte16fQu63gRmO'
FF3_df = pd.read_csv(url_3)

FF3_df['Date'] = pd.to_datetime(FF3_df['Date'], format='%Y%m%d')

# %%
FF3_df
# Out:
#             Date  Mkt-RF   SMB   HML     RF
# 0     1926-07-01    0.10 -0.25 -0.27  0.009
# 1     1926-07-02    0.45 -0.33 -0.06  0.009
# 2     1926-07-06    0.17  0.30 -0.39  0.009
# 3     1926-07-07    0.09 -0.58  0.02  0.009
# 4     1926-07-08    0.21 -0.38  0.19  0.009
# ...          ...     ...   ...   ...    ...
# 25749 2024-05-24    0.72  0.03  0.16  0.020
# 25750 2024-05-28   -0.04  0.28 -0.90  0.020
# 25751 2024-05-29   -0.77 -0.29 -0.62  0.020
# 25752 2024-05-30   -0.53  1.04  1.00  0.020
# 25753 2024-05-31    0.68 -0.36  0.78  0.020
#
# [25754 rows x 5 columns]

# %%
# Filter data for the chosen period
start_date = '2021-05-01'
end_date = '2024-05-31'
mask = (FF3_df['Date'] >= start_date) & (FF3_df['Date'] <= end_date)
FF3_df1 = FF3_df.loc[mask]
FF3_df1
# Out:
#             Date  Mkt-RF   SMB   HML    RF
# 24978 2021-05-03    0.17  0.44  1.71  0.00
# 24979 2021-05-04   -0.89 -0.75  2.00  0.00
# 24980 2021-05-05   -0.06 -0.47  1.34  0.00
# 24981 2021-05-06    0.48 -0.83  1.20  0.00
# 24982 2021-05-07    0.84  0.43 -0.10  0.00
# ...          ...     ...   ...   ...   ...
# 25749 2024-05-24    0.72  0.03  0.16  0.02
# 25750 2024-05-28   -0.04  0.28 -0.90  0.02
# 25751 2024-05-29   -0.77 -0.29 -0.62  0.02
# 25752 2024-05-30   -0.53  1.04  1.00  0.02
# 25753 2024-05-31    0.68 -0.36  0.78  0.02
#
# [776 rows x 5 columns]

# %% [markdown]
# To calculate the coefficient, we should refer to the following equation:
#
# $$
# R_i - R_f = \alpha_i + \beta_1(R_m - R_f) + \beta_2SMB + \beta_3HML
# $$
#
# Next, we are going to use OLS and Robust Regression (Huber) to find out the intercept (Alpha) and coefficient (Factor Loading), as well as its corresponding p-value.

# %% [markdown]
# Before we proceed, we would like to recap the portfolio dataset that we have identified previously. The portfolio dataset treated as Ri.
#
# In this case, we use one of the portfolio (SH) for analysis. SH stands for Small Size and high Book-to-Market Value.

# %%
## Input RF of FF3 Factor Return DF to Portfolio DF
mergedFF3_df = pd.merge(portfolio_df1, FF3_df1[['Date', 'RF']], on='Date', how='left')
mergedFF3_df
# Out:
#           Date  SMALL LoBM  ME1 BM2  SMALL HiBM  BIG LoBM  ME2 BM2  BIG HiBM  \
# 0   2021-05-03        0.11     0.53        1.02      0.04     0.46      0.90
# 1   2021-05-04       -1.96    -1.10       -0.45     -1.53    -0.66     -0.25
# 2   2021-05-05        0.10     0.31        0.58      0.05     0.44      1.17
# 3   2021-05-06       -0.88     0.22        0.79      0.35     0.72      1.16
# 4   2021-05-07        1.44     1.46        1.36      1.01     0.90      1.09
# ..         ...         ...      ...         ...       ...      ...       ...
# 800 2024-05-27        0.51     0.44        0.42      0.11     0.27      0.32
# 801 2024-05-28       -0.18    -0.29       -0.13      0.02    -0.42     -0.21
# 802 2024-05-29       -1.51    -1.38       -1.34     -0.69    -1.30     -1.39
# 803 2024-05-30        1.23     0.83        0.98     -0.66    -0.17      0.87
# 804 2024-05-31        0.70     0.81        0.98      0.31     1.08      1.19
#
#        RF
# 0    0.00
# 1    0.00
# ...

# %% [markdown]
# By comparing the number of rows between FF3_df1 and merged _df1, there is discrepency between these two models. This might be due to missing data from downloaded FF3 model.
#
# The following code is used to match the number of rows for both dataframes.

# %%
#To match the number of rows between the dataframes

# Identify the dates present in FF3_df1
dates_in_FF3_df1 = FF3_df1['Date'].unique()

# Remove rows in merged_df1 that have dates not present in FF3_df1
adjusted_mergedFF3_df = mergedFF3_df[mergedFF3_df['Date'].isin(dates_in_FF3_df1)]

adjusted_mergedFF3_df
# Out:
#           Date  SMALL LoBM  ME1 BM2  SMALL HiBM  BIG LoBM  ME2 BM2  BIG HiBM  \
# 0   2021-05-03        0.11     0.53        1.02      0.04     0.46      0.90
# 1   2021-05-04       -1.96    -1.10       -0.45     -1.53    -0.66     -0.25
# 2   2021-05-05        0.10     0.31        0.58      0.05     0.44      1.17
# 3   2021-05-06       -0.88     0.22        0.79      0.35     0.72      1.16
# 4   2021-05-07        1.44     1.46        1.36      1.01     0.90      1.09
# ..         ...         ...      ...         ...       ...      ...       ...
# 799 2024-05-24        0.11     0.55        0.56      0.45     0.42      0.71
# 801 2024-05-28       -0.18    -0.29       -0.13      0.02    -0.42     -0.21
# 802 2024-05-29       -1.51    -1.38       -1.34     -0.69    -1.30     -1.39
# 803 2024-05-30        1.23     0.83        0.98     -0.66    -0.17      0.87
# 804 2024-05-31        0.70     0.81        0.98      0.31     1.08      1.19
#
#        RF
# 0    0.00
# 1    0.00
# ...

# %%
# Convert the columns to numeric, handling potential errors
#adjusted_mergedFF3_df['SMALL HiBM'] = pd.to_numeric(adjusted_mergedFF3_df['SMALL HiBM'], errors='coerce')
#adjusted_mergedFF3_df['RF'] = pd.to_numeric(adjusted_mergedFF3_df['RF'], errors='coerce')

#added the code
# Check if DataFrame is defined
if 'adjusted_mergedFF3_df' in globals():
    # Check if columns exist in DataFrame
    if 'SMALL HiBM' in adjusted_mergedFF3_df.columns and 'RF' in adjusted_mergedFF3_df.columns:
        try:
            # Convert 'SMALL HiBM' column to numeric, coercing errors into NaNs
            adjusted_mergedFF3_df.loc[:, 'SMALL HiBM'] = pd.to_numeric(adjusted_mergedFF3_df['SMALL HiBM'], errors='coerce')
            print("Converted 'SMALL HiBM' successfully")
        except Exception as e:
            print(f"Error converting 'SMALL HiBM': {e}")

        try:
            # Convert 'RF' column to numeric, coercing errors into NaNs
            adjusted_mergedFF3_df.loc[:, 'RF'] = pd.to_numeric(adjusted_mergedFF3_df['RF'], errors='coerce')
            print("Converted 'RF' successfully")
        except Exception as e:
            print(f"Error converting 'RF': {e}")
    else:
        print("Columns 'SMALL HiBM' and/or 'RF' do not exist in the DataFrame")
else:
    print("DataFrame 'adjusted_mergedFF3_df' is not defined")


# Assign to y and X
y1 = adjusted_mergedFF3_df['SMALL HiBM'] - adjusted_mergedFF3_df['RF'] #SH
X1 = FF3_df1[['Mkt-RF','SMB', 'HML']] #CMA nad RMW are not involved.
# Out:
# Converted 'SMALL HiBM' successfully
# Converted 'RF' successfully

# %%
#Split the data into Training (80%) and Testing (20%) dataset
from sklearn.model_selection import train_test_split

# Split the data into training and test sets
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=42)

# %% [markdown]
# We'll use statsmodels to perform the OLS regression

# %%
import statsmodels.api as sm

# Reset the indices after the splitting
X1_train = X1_train.reset_index(drop=True)
y1_train = y1_train.reset_index(drop=True)

# Add a constant to the features (as intercept)
X1_train_const = sm.add_constant(X1_train)

# Fit the OLS model
olsFF3_model = sm.OLS(y1_train, X1_train_const).fit()

# Print the summary of the OLS regression
print(olsFF3_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     769.6
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):          7.61e-208
# Time:                        16:58:09   Log-Likelihood:                -313.52
# No. Observations:                 620   AIC:                             635.0
# Df Residuals:                     616   BIC:                             652.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0022      0.016     -0.136      0.892      -0.034       0.030
# ...

# %%
X1_train
# Out:
#      Mkt-RF   SMB   HML
# 0     -0.27  1.08  0.03
# 1      0.95  0.62  0.79
# 2      0.77  0.20 -1.22
# 3     -0.33  0.21  0.09
# 4     -0.81  0.04  0.77
# ..      ...   ...   ...
# 615    0.24 -0.59 -0.40
# 616    1.10  0.41  0.50
# 617    2.18  0.20 -0.62
# 618   -0.16 -0.23  0.20
# 619   -0.10  1.26  2.43
#
# [620 rows x 3 columns]

# %%
y1_train
# Out:
# 0      0.630
# 1      1.630
# 2      0.244
# 3      0.358
# 4     -0.481
#        ...
# 615   -0.220
# 616    0.370
# 617    1.159
# 618    0.143
# 619    0.980
# Length: 620, dtype: float64

# %% [markdown]
# Next, we will run Robust Regression.

# %%
#Step3a2: Robust Regression
# Fit the robust regression model
#robustFF3_model = sm.RLM(y1_train, X1_train_const, M=sm.robust.norms.HuberT()).fit()

# Print the summary of the robust regression
#print(robustFF3_model.summary())

# %%
#Step3a2: Robust Regression
# Check indices
print("y1_train indices:")
print(y1_train.index)
print("X1_train_const indices:")
print(X1_train_const.index)

# Align indices if necessary
# If indices are not aligned, align them:
if not y1_train.index.equals(X1_train_const.index):
    print("Indices are not aligned. Aligning indices...")
    common_index = y1_train.index.intersection(X1_train_const.index)
    y1_train = y1_train.loc[common_index]
    X1_train_const = X1_train_const.loc[common_index]

# Check again to ensure they are aligned
print("Aligned y1_train indices:")
print(y1_train.index)
print("Aligned X1_train_const indices:")
print(X1_train_const.index)

# Step 3: Fit the robust regression model
robustFF3_model = sm.RLM(y1_train, X1_train_const, M=sm.robust.norms.HuberT()).fit()

# Print the summary of the robust regression
print(" Printing the summary of the robust regression")
print(robustFF3_model.summary())
# Out:
# y1_train indices:
# RangeIndex(start=0, stop=620, step=1)
# X1_train_const indices:
# RangeIndex(start=0, stop=620, step=1)
# Aligned y1_train indices:
# RangeIndex(start=0, stop=620, step=1)
# Aligned X1_train_const indices:
# RangeIndex(start=0, stop=620, step=1)
#  Printing the summary of the robust regression
#                     Robust linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                  620
# Model:                            RLM   Df Residuals:                      616
# Method:                          IRLS   Df Model:                            3
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Wed, 24 Jul 2024
# Time:                        16:58:09
# No. Iterations:                    18
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# In Step 3b, we are going to summarise the beta coefficient and alpha intercept.

# %%
# Summary of coefficients and metrics
summaryFF3_df = pd.DataFrame({
    'OLS Coefficients': olsFF3_model.params,
    'OLS P-values': olsFF3_model.pvalues,
    'Robust Coefficients': robustFF3_model.params,
    'Robust P-values': robustFF3_model.pvalues
})

print(summaryFF3_df)
# Out:
#         OLS Coefficients   OLS P-values  Robust Coefficients  Robust P-values
# const          -0.002200   8.921937e-01             0.003164     8.421678e-01
# Mkt-RF          0.622658  7.192311e-170             0.624574     0.000000e+00
# SMB             0.359732   2.823311e-41             0.373758     1.626274e-53
# HML             0.363484   1.297106e-74             0.353830     2.226343e-97

# %%
print("Step 3 completed")
# Out:
# Step 3 completed

# %% [markdown]
# # Step 4: Study on FF5 Beta Coefficient
#
# As we have imported the FF5 and portfolio return dataframe in Step 2, we will skip the data import in this section

# %% [markdown]
# To calculate the coefficient in FF5, we should refer to the following equation:
#
# $$
# R_i - R_f = \alpha_i + \beta_1(R_m - R_f) + \beta_2SMB + \beta_3HML + \beta_4RMW + \beta_5CMA
# $$
#
# Next, we are going to use OLS and Robust Regression (Huber) to find out the intercept (Alpha) and coefficient (Factor Loading), as well as its corresponding p-value.

# %%
# Input RF of Factor Return DF to Portfolio DF
mergedFF5_df = pd.merge(portfolio_df1, FF5_df1[['Date', 'RF']], on='Date', how='left')
mergedFF5_df
# Out:
#           Date  SMALL LoBM  ME1 BM2  SMALL HiBM  BIG LoBM  ME2 BM2  BIG HiBM  \
# 0   2021-05-03        0.11     0.53        1.02      0.04     0.46      0.90
# 1   2021-05-04       -1.96    -1.10       -0.45     -1.53    -0.66     -0.25
# 2   2021-05-05        0.10     0.31        0.58      0.05     0.44      1.17
# 3   2021-05-06       -0.88     0.22        0.79      0.35     0.72      1.16
# 4   2021-05-07        1.44     1.46        1.36      1.01     0.90      1.09
# ..         ...         ...      ...         ...       ...      ...       ...
# 800 2024-05-27        0.51     0.44        0.42      0.11     0.27      0.32
# 801 2024-05-28       -0.18    -0.29       -0.13      0.02    -0.42     -0.21
# 802 2024-05-29       -1.51    -1.38       -1.34     -0.69    -1.30     -1.39
# 803 2024-05-30        1.23     0.83        0.98     -0.66    -0.17      0.87
# 804 2024-05-31        0.70     0.81        0.98      0.31     1.08      1.19
#
#        RF
# 0    0.00
# 1    0.00
# ...

# %%
# Convert the columns to numeric, handling potential errors
mergedFF5_df['SMALL HiBM'] = pd.to_numeric(mergedFF5_df['SMALL HiBM'], errors='coerce')
mergedFF5_df['RF'] = pd.to_numeric(mergedFF5_df['RF'], errors='coerce')

# Assign to y and X
y2 = mergedFF5_df['SMALL HiBM'] - mergedFF5_df['RF'] #SH
X2 = FF5_df1[['Mkt-RF','SMB', 'HML', 'RMW', 'CMA']]

#Split the data into Training (80%) and Testing (20%) dataset
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=42)

# %%
#Step4a1: OLS Regression
#Next, use Statsmodels to perform OLS Regression
# Add a constant to the features (As intercept)
#X2_train_const = sm.add_constant(X2_train)

#Reset the indices afer the splitting
#X2_train = X2_train.reset_index(drop=True)
#y2_train = y2_train.reset_index(drop=True)

# Fit the OLS model
#olsFF5_model = sm.OLS(y2_train, X2_train_const).fit()

# Print the summary of the OLS regression
#print(olsFF5_model.summary())

#Replaced with below code:

# Reset the indices after the splitting
X2_train = X2_train.reset_index(drop=True)
y2_train = y2_train.reset_index(drop=True)

# Add a constant to the features (as intercept)
X2_train_const = sm.add_constant(X2_train)

# Fit the OLS model
olsFF5_model = sm.OLS(y2_train, X2_train_const).fit()

# Print the summary of the OLS regression
print(olsFF5_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 1.243e+04
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):               0.00
# Time:                        16:58:09   Log-Likelihood:                 654.00
# No. Observations:                 644   AIC:                            -1296.
# Df Residuals:                     638   BIC:                            -1269.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0101      0.004      2.886      0.004       0.003       0.017
# ...

# %%
#Step4a2: Robust Regression

# Fit the robust regression model
robustFF5_model = sm.RLM(y2_train, X2_train_const, M=sm.robust.norms.HuberT()).fit()

# Print the summary of the robust regression
print(robustFF5_model.summary())
# Out:
#                     Robust linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                  644
# Model:                            RLM   Df Residuals:                      638
# Method:                          IRLS   Df Model:                            5
# Norm:                          HuberT
# Scale Est.:                       mad
# Cov Type:                          H1
# Date:                Wed, 24 Jul 2024
# Time:                        16:58:09
# No. Iterations:                    20
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0103      0.003      2.955      0.003       0.003       0.017
# Mkt-RF         0.9754      0.005    202.877      0.000       0.966       0.985
# SMB            0.7955      0.010     78.390      0.000       0.776       0.815
# ...

# %%
print("Step 4 completed")
# Out:
# Step 4 completed

# %%
#Step 4b
# Summary of coefficients and metrics
summaryFF5_df = pd.DataFrame({
    'OLS Coefficients': olsFF5_model.params,
    'OLS P-values': olsFF5_model.pvalues,
    'Robust Coefficients': robustFF5_model.params,
    'Robust P-values': robustFF5_model.pvalues
})

print(summaryFF5_df)
# Out:
#         OLS Coefficients   OLS P-values  Robust Coefficients  Robust P-values
# const           0.010119   4.032014e-03             0.010278         0.003129
# Mkt-RF          0.973021   0.000000e+00             0.975430         0.000000
# SMB             0.796060   0.000000e+00             0.795499         0.000000
# HML             0.403947  1.710751e-164             0.409005         0.000000
# RMW            -0.015632   1.914549e-01            -0.013815         0.244050
# CMA            -0.039701   1.100103e-02            -0.044137         0.004268

# %% [markdown]
# # Step 5: Using the daily factor data:
# c. Compute the correlation matrix of the factor returns
# d. Compute the covariance matrix of the factor returns.
# e. Compare and contrast the 2 matrices, emphasizing any important
# differences.

# %% [markdown]
# ##Step 5 Part 1: Correlation and Covariance Matrix of FF3 Model

# %%
# Calculate the correlation matrix
required_columns = ['Date','Mkt-RF','SMB', 'HML']
correlation_matrix_FF3 = FF3_df1[required_columns[1:]].corr()

print("\nCorrelation matrix in FF3 factor returns:")
print(correlation_matrix_FF3)

# Plot the correlation matrix
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix_FF3, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of FF3 Factor Returns (2021-2024)')
plt.show()

# Calculate the covariance matrix
covariance_matrix_FF3 = FF3_df1[required_columns[1:]].cov()

print("\nCovariance matrix in FF3 factor returns:")
print(covariance_matrix_FF3)

# Plot the covariance matrix
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(covariance_matrix_FF3, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Covariance Matrix of FF3 Factor Returns (2021-2024)')
plt.show()
# Out:
# Correlation matrix in FF3 factor returns:
#           Mkt-RF       SMB       HML
# Mkt-RF  1.000000  0.345130 -0.355765
# SMB     0.345130  1.000000 -0.184211
# HML    -0.355765 -0.184211  1.000000
# Covariance matrix in FF3 factor returns:
#           Mkt-RF       SMB       HML
# Mkt-RF  1.285291  0.272430 -0.395500
# SMB     0.272430  0.484778 -0.125768
# HML    -0.395500 -0.125768  0.961538

# %% [markdown]
# ##Step 5 Part 2: Correlation and Covariance Matrix of FF5 Model

# %%
# Calculate the correlation matrix
required_columns = ['Date','Mkt-RF','SMB', 'HML', 'RMW', 'CMA']
correlation_matrix_FF5 = FF5_df1[required_columns[1:]].corr()

print("\nCorrelation matrix in FF5 factor returns:")
print(correlation_matrix_FF5)

# Plot the correlation matrix
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix_FF5, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of FF5 Factor Returns (2021-2024)')
plt.show()

# Calculate the covariance matrix
covariance_matrix_FF5 = FF5_df1[required_columns[1:]].cov()

print("\nCovariance matrix in FF5 factor returns:")
print(covariance_matrix_FF5)

# Plot the covariance matrix
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.heatmap(covariance_matrix_FF5, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Covariance Matrix of FF5 Factor Returns (2021-2024)')
plt.show()
# Out:
# Correlation matrix in FF5 factor returns:
#           Mkt-RF       SMB       HML       RMW       CMA
# Mkt-RF  1.000000 -0.252972 -0.358068 -0.169865 -0.549438
# SMB    -0.252972  1.000000  0.248601 -0.346941  0.130793
# HML    -0.358068  0.248601  1.000000 -0.229489  0.819828
# RMW    -0.169865 -0.346941 -0.229489  1.000000  0.058302
# CMA    -0.549438  0.130793  0.819828  0.058302  1.000000
# Covariance matrix in FF5 factor returns:
#           Mkt-RF       SMB       HML       RMW       CMA
# Mkt-RF  0.878967 -0.094613 -0.222449 -0.055031 -0.253343
# SMB    -0.094613  0.159144  0.065717 -0.047826  0.025662
# HML    -0.222449  0.065717  0.439094 -0.052548  0.267181
# RMW    -0.055031 -0.047826 -0.052548  0.119408  0.009908
# CMA    -0.253343  0.025662  0.267181  0.009908  0.241885

# %%
print("Step 5 completed")
# Out:
# Step 5 completed

# %% [markdown]
# ## Comparison between FF3 and FF5

# %% [markdown]
# Some key findings from the chart above:
# By adding RMW and CMA, we noticed the correlation of Mkt-RF/SMB and SMB/HML are changed, from positive to negative.
# In FF5, we noticed RMW does not have significant correlation with CMA (0.058).
# The strongest correlation is HML/CMA, that aligns with our interpretation in Step 2b.
# By adding RMW and CMA, the covariance between Mkt-RF, SMB and HML are reduced, showing the impact to the change in return is reduced by additional factor return from FF5.
# The significant covariance value is Mkt-RF/CMA and HML/CMA, that aligns to our interpretation in Step 2b.

# %% [markdown]
# # Step 6: Report in tabular form how the extra 2 factors (CMA and RMW) affect the results.

# %%
# Definite the function to store R-squared and MSE
from sklearn.linear_model import LinearRegression, HuberRegressor
from sklearn.metrics import mean_squared_error, r2_score
# Function to evaluate linear regression model
def linear_regression(X_train, X_test, y_train, y_test):
    results = {}
    model = LinearRegression()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    results['mse'] = mean_squared_error(y_test, predictions)
    results['r2'] = r2_score(y_test, predictions)
    return results

# Function to evaluate linear regression model
def robust_regression(X_train, X_test, y_train, y_test):
    results = {}
    model = HuberRegressor()
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    results['mse'] = mean_squared_error(y_test, predictions)
    results['r2'] = r2_score(y_test, predictions)
    return results

# %%
# Perform regressions and collect results
results = {
    'lin_FF3': linear_regression(X1_train, X1_test, y1_train, y1_test),
    'robust_FF3': robust_regression(X1_train, X1_test, y1_train, y1_test),
    'lin_FF5': linear_regression(X2_train, X2_test, y2_train, y2_test),
    'robust_FF5': robust_regression(X2_train, X2_test, y2_train, y2_test)
}

# Convert results to a DataFrame for tabular display
df_results = pd.DataFrame(results).T

# Display the DataFrame
df_results
# Out:
#                  mse        r2
# lin_FF3     0.149446  0.810407
# robust_FF3  0.148912  0.811085
# lin_FF5     0.006771  0.990399
# robust_FF5  0.006725  0.990464

# %%
print("Step 6 completed")
# Out:
# Step 6 completed

# %% [markdown]
# By adding two factors in FF5, we noticed MSE and r2 have improved.

# %% [markdown]
# # Step 7: Select ANY 5 stocks (over the same 3-year period) that you combine in a
# portfolio.
# f. Use Markowitz portfolio optimization to find a set of optimal allocations.
# (Shorts are possible).
# g. Show how the portfolio depends on each of the factors in FF3.
# h. Show how the portfolio depends on each of the factors in FF5.

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import cvxopt as opt
#import cvxopt.solvers as optsolvers
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import statsmodels.api as sm

# Step 2: Download historical stock prices
tickers = ['AAPL', 'PZZA', 'MSFT', 'AMZN', 'TSLA']
stocks = ['AAPL', 'PZZA', 'MSFT', 'AMZN', 'TSLA']
# Define the 3-year period
start_date = '2018-01-01'
end_date = '2020-12-31'

data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Step 3: Calculate daily returns
returns = data.pct_change().dropna()

# Step 4: Markowitz Portfolio Optimization

# Function to calculate portfolio performance metrics
def portfolio_performance(weights, mean_returns, cov_matrix):
    returns = np.sum(weights * mean_returns) * 252
    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
    return std, returns

# Objective function to minimize (negative Sharpe ratio)
def negative_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
    std, returns = portfolio_performance(weights, mean_returns, cov_matrix)
    return -((returns - risk_free_rate) / std)

# Function to find the optimal portfolio
def optimize_portfolio(mean_returns, cov_matrix, risk_free_rate):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix, risk_free_rate)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bounds = tuple((-1, 1) for _ in range(num_assets))
    result = minimize(negative_sharpe_ratio, num_assets * [1. / num_assets,], args=args,
                      method='SLSQP', bounds=bounds, constraints=constraints)
    return result

# Calculating mean returns and covariance matrix
mean_returns = returns.mean()
cov_matrix = returns.cov()
risk_free_rate = 0.01

# Finding the optimal portfolio
optimal_portfolio = optimize_portfolio(mean_returns, cov_matrix, risk_free_rate)

# Optimal weights
optimal_weights = optimal_portfolio.x

print("optimal weights")
optimal_weights

print("Optimal Portfolio Weights:")
for ticker, weight in zip(tickers, optimal_weights):
    print(f"{ticker}: {weight:.2%}")
# Out:
# [*********************100%%**********************]  5 of 5 completed
# optimal weights
# Optimal Portfolio Weights:
# AAPL: 42.32%
# PZZA: 27.05%
# MSFT: -8.02%
# AMZN: -0.39%
# TSLA: 39.04%

# %%
print("Risk free rate used is: 0.01")
print("Mean returns")
mean_returns
# Out:
# Risk free rate used is: 0.01
# Mean returns
# Ticker
# AAPL    0.001800
# AMZN    0.001568
# MSFT    0.001520
# PZZA    0.001037
# TSLA    0.004086
# dtype: float64

# %%
print("Covariance Matrix")
cov_matrix
# Out:
# Covariance Matrix
# Ticker      AAPL      AMZN      MSFT      PZZA      TSLA
# Ticker
# AAPL    0.000489  0.000303  0.000346  0.000177  0.000392
# AMZN    0.000303  0.000438  0.000313  0.000175  0.000353
# MSFT    0.000346  0.000313  0.000413  0.000182  0.000386
# PZZA    0.000177  0.000175  0.000182  0.000936  0.000334
# TSLA    0.000392  0.000353  0.000386  0.000334  0.001849

# %%
print("Portfolio Returns")
# Calculate the portfolio returns
portfolio_returns = (returns * optimal_weights).sum(axis=1)
portfolio_returns
# Out:
# Portfolio Returns
# Date
# 2018-01-03   -0.001047
# 2018-01-04   -0.000812
# 2018-01-05    0.010620
# 2018-01-08    0.026698
# 2018-01-09   -0.001969
#                 ...
# 2020-12-23   -0.000293
# 2020-12-24    0.011098
# 2020-12-28    0.024886
# 2020-12-29   -0.000700
# 2020-12-30    0.011252
# Length: 754, dtype: float64

# %%
import pandas as pd
import zipfile
import io
import requests

# Step 1: Download the ZIP file from the URL
zip_url = 'https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_Factors_daily_CSV.zip'
response = requests.get(zip_url)
zip_file = io.BytesIO(response.content)  # Use BytesIO to handle the file-like object in memory

# Step 2: Unzip the file and read the CSV data
with zipfile.ZipFile(zip_file) as z:
    # List all files in the ZIP archive
    file_names = z.namelist()
    print("Files in ZIP:", file_names)

    # Assuming the ZIP file contains only one CSV file
    csv_file_name = file_names[0]

    # Read the CSV file
    with z.open(csv_file_name) as f:
        ff3_factors = pd.read_csv(f, index_col=0, parse_dates=True,skiprows=3)
# Out:
# Files in ZIP: ['F-F_Research_Data_Factors_daily.CSV']

# %%
# Delete the last row as there is copy right text which is not data
ff3_factors = ff3_factors.iloc[:-1]

# %%
ff3_factors
# Out:
#           Mkt-RF   SMB   HML     RF
# 19260701    0.10 -0.25 -0.27  0.009
# 19260702    0.45 -0.33 -0.06  0.009
# 19260706    0.17  0.30 -0.39  0.009
# 19260707    0.09 -0.58  0.02  0.009
# 19260708    0.21 -0.38  0.19  0.009
# ...          ...   ...   ...    ...
# 20240524    0.72  0.03  0.16  0.020
# 20240528   -0.04  0.28 -0.90  0.020
# 20240529   -0.77 -0.29 -0.62  0.020
# 20240530   -0.53  1.04  1.00  0.020
# 20240531    0.68 -0.36  0.78  0.020
#
# [25754 rows x 4 columns]

# %%
ff3_factors.index = pd.to_datetime(ff3_factors.index, format='%Y%m%d')
ff3_factors = ff3_factors[['Mkt-RF', 'SMB', 'HML']] / 100  # Assuming factors are in percentage format

# Ensure the dates align properly
returns.index = returns.index.tz_localize(None)  # Remove timezone info if present
ff3_factors.index = ff3_factors.index.tz_localize(None)

# Align the dates and drop any rows with missing values
aligned_data_ff3 = returns.join(ff3_factors, how='inner').dropna()

# Define the portfolio returns as the average of the stock returns (example portfolio)
aligned_data_ff3['Portfolio_Return'] = aligned_data_ff3[tickers].mean(axis=1)

# Add a constant to the factors
X_ff3 = sm.add_constant(aligned_data_ff3[['Mkt-RF', 'SMB', 'HML']])
y_ff3 = aligned_data_ff3['Portfolio_Return']

# Perform the regression
model_ff3 = sm.OLS(y_ff3, X_ff3).fit()
print(model_ff3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Portfolio_Return   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     553.5
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):          1.28e-189
# Time:                        16:58:13   Log-Likelihood:                 2318.7
# No. Observations:                 754   AIC:                            -4629.
# Df Residuals:                     750   BIC:                            -4611.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.000      2.224      0.026       0.000       0.002
# ...

# %%
import pandas as pd
import zipfile
import io
import requests

# Step 1: Download the ZIP file from the URL
zip_url2 = 'https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/ftp/F-F_Research_Data_5_Factors_2x3_daily_CSV.zip'
response = requests.get(zip_url2)
zip_file = io.BytesIO(response.content)  # Use BytesIO to handle the file-like object in memory

# Step 2: Unzip the file and read the CSV data
with zipfile.ZipFile(zip_file) as z:
    # List all files in the ZIP archive
    file_names = z.namelist()
    print("Files in ZIP:", file_names)

    # Assuming the ZIP file contains only one CSV file
    csv_file_name = file_names[0]

    # Read the CSV file
    with z.open(csv_file_name) as f:
        ff5_factors = pd.read_csv(f, index_col=0, parse_dates=True,skiprows=3)
# Out:
# Files in ZIP: ['F-F_Research_Data_5_Factors_2x3_daily.CSV']

# %%
ff5_factors
# Out:
#             Mkt-RF   SMB   HML   RMW   CMA     RF
# 1963-07-01   -0.67  0.02 -0.35  0.03  0.13  0.012
# 1963-07-02    0.79 -0.28  0.28 -0.08 -0.21  0.012
# 1963-07-03    0.63 -0.18 -0.10  0.13 -0.25  0.012
# 1963-07-05    0.40  0.09 -0.28  0.07 -0.30  0.012
# 1963-07-08   -0.63  0.07 -0.20 -0.27  0.06  0.012
# ...            ...   ...   ...   ...   ...    ...
# 2024-05-24    0.72  0.16  0.16  0.30 -0.39  0.020
# 2024-05-28   -0.04  0.13 -0.90  0.11 -1.12  0.020
# 2024-05-29   -0.77 -0.40 -0.62  0.47 -0.02  0.020
# 2024-05-30   -0.53  1.37  1.00  0.34  1.07  0.020
# 2024-05-31    0.68 -0.02  0.78  0.94  0.80  0.020
#
# [15334 rows x 6 columns]

# %%
ff5_factors.index = pd.to_datetime(ff5_factors.index, format='%Y%m%d')
ff5_factors = ff5_factors[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']] / 100  # Assuming factors are in percentage format

# Ensure the dates align properly
ff5_factors.index = ff5_factors.index.tz_localize(None)

# Align the dates and drop any rows with missing values
aligned_data_ff5 = returns.join(ff5_factors, how='inner').dropna()

# Define the portfolio returns as the average of the stock returns (example portfolio)
aligned_data_ff5['Portfolio_Return'] = aligned_data_ff5[tickers].mean(axis=1)

# Add a constant to the factors
X_ff5 = sm.add_constant(aligned_data_ff5[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']])
y_ff5 = aligned_data_ff5['Portfolio_Return']

# Perform the regression
model_ff5 = sm.OLS(y_ff5, X_ff5).fit()
print(model_ff5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Portfolio_Return   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     350.7
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):          2.63e-193
# Time:                        16:58:13   Log-Likelihood:                 2333.7
# No. Observations:                 754   AIC:                            -4655.
# Df Residuals:                     748   BIC:                            -4628.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.000      2.312      0.021       0.000       0.002
# ...

# %%
# Generate random portfolios for the efficient frontier
def generate_random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate):
    results = np.zeros((3, num_portfolios))
    weights_record = []
    for i in range(num_portfolios):
        weights = np.random.random(len(mean_returns))
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    return results, weights_record

num_portfolios = 50000
results, weights_record = generate_random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate)

# Plotting the efficient frontier
plt.figure(figsize=(10, 6))
plt.scatter(results[0,:], results[1,:], c=results[2,:], marker='o', alpha=0.3)
plt.title('Efficient Frontier')
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Return')
plt.colorbar(label='Sharpe Ratio')

# Mark the optimal portfolio
opt_std_dev, opt_return = portfolio_performance(optimal_weights, mean_returns, cov_matrix)
plt.scatter(opt_std_dev, opt_return, marker='*', color='r', s=200, label='Optimal Portfolio')

# Plot individual stocks
for ticker in tickers:
    stock_return = mean_returns[ticker] * 252
    stock_std_dev = np.std(returns[ticker]) * np.sqrt(252)
    plt.scatter(stock_std_dev, stock_return, label=ticker, s=100)

# Display the plot
plt.legend(loc='upper left')
plt.show()

# %%
print("Step 7 Completed")
# Out:
# Step 7 Completed

# %%
print("Code run Complete")
# Out:
# Code run Complete

# %% [markdown]
# # Step 8: Result and Intepretation

# %% [markdown]
# Summarization of findings and interpretation:
#
#
#
#
# Page 15 of 16
# For **FF3** and **FF5**, the R-squared values of 0.689 (FF3) and 0.701 (FF5) are suggesting that both models explain a substantial portion of the portfolio's variance and is explained by the 3 factors Market, size and value. All in all, based on FF3 and FF5 model interpretations on 5 stocks, a strong market dependency of the portfolio shown, a preference for growth over value stocks, leaning towards companies with aggressive investment strategies.
# Interpretation from step 7 results:
#
#
#
#
#
#
# 1.   **Market Risk Premium (Mkt-RF):**
# a.   FF3 Model Interpretation: A strong positive sensitivity of the portfolio returns to the market, with a beta of 1.1080. Portfolio is moving with the overall market significantly.
# b.   FF5 Model Interpretation: Value remained high (Coefficient: 1.0526 ) and positive, strong correlation with the market. With a slightly lower beta compared to FF3 model.
#
#
#
#
#
# 2.   **Size Factor (SMB)**
# a.   FF3 Model Interpretation: Small Minus Big, the coefficient of 0.1849 showing a positive relationship with small-cap stocks.
# b.   FF5 Model Interpretation: SMB coefficient is still positive but smaller (0.0833) than in the FF3 model (0.1849), indicating a smaller lean or tilt towards smaller companies.
#
#
#
#
#
# 3.   **Value Factor (HML)**
# a.   FF3  Model  Interpretation:  Negative  value  of  coefficient  of  -0.5850  shows  a  strong preference for growth stocks vs. Value stocks
# b.   FF5 Model Interpretation: Coefficient continued to be negative, -0.4656 showing a strong preference for growth over value stocks
#
#
#
#
#
#
# 4.   **Profitability Factor (RMW)**
# a. FF5 Model Interpretation: Though the coefficient is positive value of 0.1159, p-value is 0.255 which is not that significant (statistically) This is indicating profitability is not heavily influencing the portfolio but slight tilt towards companies with profitability(robust)
#
#
#
#
#
#
#
# 5.   **Investment Factor (CMA)**
# a.   FF5 Model Interpretation: The coefficient is negative of -0.747035 and is significant, showing a preference for companies with more investment strategies that are aggressive
